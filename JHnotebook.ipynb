# %%
url = "https://raw.githubusercontent.com/atolentino/JH-replication/master/LocSCSubpar.csv"
df = pd.read_csv(url)
df
# Out:
#         Location  AVG_SC_Rating  PTS  FGP  C3PCT  FTP  AST  TOV
# 0        Atlanta           3.55    3    2      0    2    1    3
# 1         Boston           3.82    3    4      7    3    3    5
# 2       Brookyln           3.62    4    4      3    2    2    3
# 3      Charlotte           3.31    3    6      4    3    1    3
# 4        Chicago           3.95    4    6      3    5    2    4
# 5      Cleveland           3.29    3    3      3    3    1    3
# 6             DC           3.69    2    1      3    2    1    5
# 7         Dallas           3.74    6    5      4    4    4    3
# 8         Denver           3.62    5    4      5    5    4    4
# 9        Detroit           3.71    2    3      2    4    0    4
# 10  Indianapolis           3.48    5    4      3    3    3    6
# 11    LosAngeles           3.94    5    3      2    6    2    2
# 12       Memphis           3.65    6    4      5    3    5    3
# 13         Miami           4.03    3    5      3    2    4    5
# ...

# %%
df['Total'] = df.iloc[:, -6:].sum(axis=1)
df
# Out:
#         Location  AVG_SC_Rating  PTS  FGP  C3PCT  FTP  AST  TOV  Total
# 0        Atlanta           3.55    3    2      0    2    1    3     11
# 1         Boston           3.82    3    4      7    3    3    5     25
# 2       Brookyln           3.62    4    4      3    2    2    3     18
# 3      Charlotte           3.31    3    6      4    3    1    3     20
# 4        Chicago           3.95    4    6      3    5    2    4     24
# 5      Cleveland           3.29    3    3      3    3    1    3     16
# 6             DC           3.69    2    1      3    2    1    5     14
# 7         Dallas           3.74    6    5      4    4    4    3     26
# 8         Denver           3.62    5    4      5    5    4    4     27
# 9        Detroit           3.71    2    3      2    4    0    4     15
# 10  Indianapolis           3.48    5    4      3    3    3    6     24
# 11    LosAngeles           3.94    5    3      2    6    2    2     20
# ...

# %%
df.plot(x='AVG_SC_Rating', y='Total', style='o')
plt.title('SC Rating vs Subpar Stats')
plt.xlabel('SC Rating')
plt.ylabel('Subpar Stat Occurences')
plt.show()

# %%
X = df.iloc[:, 1].values
y = df.iloc[:, -1].values
X = sm.add_constant(X)

# %%
print(X)
print(y)
# Out:
# [[1.   3.55]
#  [1.   3.82]
#  [1.   3.62]
#  [1.   3.31]
#  [1.   3.95]
#  [1.   3.29]
#  [1.   3.69]
#  [1.   3.74]
#  [1.   3.62]
#  [1.   3.71]
#  [1.   3.48]
#  [1.   3.94]
#  [1.   3.65]
#  [1.   4.03]
#  [1.   3.42]
#  [1.   3.35]
#  [1.   3.91]
#  [1.   3.87]
#  [1.   3.76]
#  [1.   3.75]
#  [1.   3.55]
#  [1.   3.74]
#  [1.   3.75]
#  [1.   3.64]
#  [1.   3.95]
#  [1.   3.47]
#  [1.   3.5 ]
#  [1.   2.97]]
# [11 25 18 20 24 16 14 26 27 15 24 20 26 22 20 17 19 17 26 16 12 18 19 16
#  28 18 18 17]

# %%
import statsmodels.api as sm
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.114
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     3.360
# Date:                Tue, 03 Dec 2019   Prob (F-statistic):             0.0783
# Time:                        20:15:26   Log-Likelihood:                -80.380
# No. Observations:                  28   AIC:                             164.8
# Df Residuals:                      26   BIC:                             167.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.0779     12.949     -0.315      0.755     -30.694      22.538
# ...

# %%
x = df.iloc[:, 1].values.reshape(-1,1)
y = df.iloc[:, -1].values

# %%
print(x)
print(y)
# Out:
# [[3.55]
#  [3.82]
#  [3.62]
#  [3.31]
#  [3.95]
#  [3.29]
#  [3.69]
#  [3.74]
#  [3.62]
#  [3.71]
#  [3.48]
#  [3.94]
#  [3.65]
#  [4.03]
#  [3.42]
#  [3.35]
#  [3.91]
#  [3.87]
#  [3.76]
#  [3.75]
#  [3.55]
#  [3.74]
#  [3.75]
#  [3.64]
#  [3.95]
#  [3.47]
#  [3.5 ]
#  [2.97]]
# [11 25 18 20 24 16 14 26 27 15 24 20 26 22 20 17 19 17 26 16 12 18 19 16
#  28 18 18 17]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression().fit(x, y)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.11443882615482215

# %%
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# intercept: -4.077863820622383
# slope: [6.49985482]
